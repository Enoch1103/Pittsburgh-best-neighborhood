# %%
##Final Results
East Carnegie

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

final = pd.read_csv("cleaneddata.csv")
# Add combined rank
final["CombinedRank"] = final["health_rank"] + final["education_rank"] - final["crime_rank"]
final=final.sort_values('CombinedRank', ascending=False)

final.head()
# Out:
#       neighborhood  education_rank  health_rank  crime_rank  CombinedRank
# 81   East Carnegie            82.0        204.0        11.0         275.0
# 79  Chartiers City            80.0        207.0        12.0         275.0
# 67   New Homestead            68.0        201.0         8.0         261.0
# 73            Hays            73.5        194.0        21.0         246.5
# 68         Bon Air            69.0        215.0        39.0         245.0
